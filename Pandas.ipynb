# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# # Data Types

# %%
#series_is_one_dimensional
#series takes python list as an input
series= pd.Series(["a","b","c"])
number= pd.Series([1,2,3])
series, number
# Out:
# (0    a
#  1    b
#  2    c
#  dtype: object,
#  0    1
#  1    2
#  2    3
#  dtype: int64)

# %%
#data frame is one dimensional
#data frame takes python dictonary as an input
dataframe= pd.DataFrame({"columnA":series,"columbB":number})
dataframe
# Out:
#   columnA  columbB
# 0       a        1
# 1       b        2
# 2       c        3

# %% [markdown]
# # Importing/Exporting Data

# %%
car_sales= pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
dataframe
# Out:
#   columnA  columbB
# 0       a        1
# 1       b        2
# 2       c        3

# %%
dataframe.to_csv("dataframe.csv",index=False)

# %%
dataframe_csv=pd.read_csv("dataframe.csv")
dataframe_csv
# Out:
#   columnA  columbB
# 0       a        1
# 1       b        2
# 2       c        3

# %% [markdown]
# # Attribute vs Function
# attribute is to give some meta information
#
# function is to perform some steps on the given data

# %%
#attribute
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
#function
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %% [markdown]
# # Viewing and Selecting Data

# %%
dataframe,car_sales
# Out:
# (  columnA  columbB
#  0       a        1
#  1       b        2
#  2       c        3,
#       Make Colour  Odometer (KM)  Doors       Price
#  0  Toyota  White         150043      4   $4,000.00
#  1   Honda    Red          87899      4   $5,000.00
#  2  Toyota   Blue          32549      3   $7,000.00
#  3     BMW  Black          11179      5  $22,000.00
#  4  Nissan  White         213095      4   $3,500.00
#  5  Toyota  Green          99213      4   $4,500.00
#  6   Honda   Blue          45698      4   $7,500.00
#  7   Honda   Blue          54738      4   $7,000.00
#  8  Toyota  White          60000      4   $6,250.00
#  9  Nissan  White          31600      4   $9,700.00)

# %% [markdown]
# ## .loc and .iloc
#
# loc refers to index
#
# ilock refers to position

# %%
car_sales.loc[5]
# Out:
# Make                Toyota
# Colour               Green
# Odometer (KM)        99213
# Doors                    4
# Price            $4,500.00
# Name: 5, dtype: object

# %%
car_sales.iloc[5]
# Out:
# Make                Toyota
# Colour               Green
# Odometer (KM)        99213
# Doors                    4
# Price            $4,500.00
# Name: 5, dtype: object

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
instructor_data=pd.read_csv("instructor_data.csv")
instructor_data.head(2)
# Out:
#   electric vehicle companies  average price per unit of electricity  price  \
# 0                      Waymo                                    4.9  25000
# 1                       Uber                                    5.4  63000
#
#    driver age preferred
# 0                    25
# 1                    35

# %%
instructor_data.dtypes
# Out:
# electric vehicle companies                object
# average price per unit of electricity    float64
# price                                      int64
# driver age preferred                       int64
# dtype: object

# %%
#groupby
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[$\,\.]','',regex=True).astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12896/302888404.py in <module>
# ----> 1 car_sales["Price"]=car_sales["Price"].str.replace('[$\,\.]','',regex=True).astype(int)
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5581         ):
#    5582             return self[name]
# -> 5583         return object.__getattribute__(self, name)
#    5584
#    5585     def __setattr__(self, name: str, value) -> None:
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
# ...

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[$\,\.]','').astype(int)
# Out:
# C:\Users\niles\AppData\Local\Temp/ipykernel_12896/1231048933.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"]=car_sales["Price"].str.replace('[$\,\.]','').astype(int)

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     int32
# dtypes: int32(1), int64(2), object(2)
# memory usage: 488.0+ bytes

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"]=car_sales["Make"].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_missing=pd.read_csv("car-sales-missing-data.csv")
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_missing["Odometer"].fillna(car_missing["Odometer"].mean(),inplace=True)
car_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_missing["Doors"].fillna(car_missing["Doors"].mean(),inplace=True)
car_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_missing.rename(columns = {'Odometer':'Odometer (KM)'}, inplace = True)
car_missing
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           9 non-null      object
#  1   Colour         9 non-null      object
#  2   Odometer (KM)  10 non-null     float64
#  3   Doors          10 non-null     float64
#  4   Price          8 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_missing["Odometer (KM)"]=car_missing["Odometer (KM)"].astype(int)
car_missing
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043    4.0   $4,000
# 1   Honda    Red          87899    4.0   $5,000
# 2  Toyota   Blue          92302    3.0   $7,000
# 3     BMW  Black          11179    5.0  $22,000
# 4  Nissan  White         213095    4.0   $3,500
# 5  Toyota  Green          92302    4.0   $4,500
# 6   Honda    NaN          92302    4.0   $7,500
# 7   Honda   Blue          92302    4.0      NaN
# 8  Toyota  White          60000    4.0      NaN
# 9     NaN  White          31600    4.0   $9,700

# %%
car_missing.iat[7,4]= '$7000'
car_missing
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043    4.0   $4,000
# 1   Honda    Red          87899    4.0   $5,000
# 2  Toyota   Blue          92302    3.0   $7,000
# 3     BMW  Black          11179    5.0  $22,000
# 4  Nissan  White         213095    4.0   $3,500
# 5  Toyota  Green          92302    4.0   $4,500
# 6   Honda    NaN          92302    4.0   $7,500
# 7   Honda   Blue          92302    4.0    $7000
# 8  Toyota  White          60000    4.0      NaN
# 9     NaN  White          31600    4.0   $9,700

# %%
car_missing.iat[8,4]='$8,000.0'
car_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           9 non-null      object
#  1   Colour         9 non-null      object
#  2   Odometer (KM)  10 non-null     int32
#  3   Doors          10 non-null     float64
#  4   Price          10 non-null     object
# dtypes: float64(1), int32(1), object(3)
# memory usage: 488.0+ bytes

# %%
car_missing['Price']= car_missing['Price'].str.replace('[\$\,\.]','',regex=True).astype(int)

# %%
car_missing
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043    4.0   4000
# 1   Honda    Red          87899    4.0   5000
# 2  Toyota   Blue          92302    3.0   7000
# 3     BMW  Black          11179    5.0  22000
# 4  Nissan  White         213095    4.0   3500
# 5  Toyota  Green          92302    4.0   4500
# 6   Honda    NaN          92302    4.0   7500
# 7   Honda   Blue          92302    4.0   7000
# 8  Toyota  White          60000    4.0  80000
# 9     NaN  White          31600    4.0   9700

# %%
car_missing= car_missing.sort_values(by='Price',ascending=True)

# %%
car_missing['Price'].plot(x=car_missing['Make'],y=car_missing['Price'], xlabel='CAR NAMES',ylabel="CAR PRICES");

# %%
seat=pd.Series([2,4,6,8,10,12])
car_missing["Seats"]=seat
car_missing
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 4  Nissan  White         213095    4.0   3500   10.0
# 0  Toyota  White         150043    4.0   4000    2.0
# 5  Toyota  Green          92302    4.0   4500   12.0
# 1   Honda    Red          87899    4.0   5000    4.0
# 2  Toyota   Blue          92302    3.0   7000    6.0
# 7   Honda   Blue          92302    4.0   7000    NaN
# 6   Honda    NaN          92302    4.0   7500    NaN
# 9     NaN  White          31600    4.0   9700    NaN
# 3     BMW  Black          11179    5.0  22000    8.0
# 8  Toyota  White          60000    4.0  80000    NaN

# %%
car_missing['Seats'].fillna(5,inplace=True)
car_missing
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 4  Nissan  White         213095    4.0   3500   10.0
# 0  Toyota  White         150043    4.0   4000    2.0
# 5  Toyota  Green          92302    4.0   4500   12.0
# 1   Honda    Red          87899    4.0   5000    4.0
# 2  Toyota   Blue          92302    3.0   7000    6.0
# 7   Honda   Blue          92302    4.0   7000    5.0
# 6   Honda    NaN          92302    4.0   7500    5.0
# 9     NaN  White          31600    4.0   9700    5.0
# 3     BMW  Black          11179    5.0  22000    8.0
# 8  Toyota  White          60000    4.0  80000    5.0

# %%
car_missing.plot(x=car_missing['Seats'],y=car_missing['Price'], xlabel='CAR Seats',ylabel="CAR PRICES")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12896/3493177903.py in <module>
# ----> 1 car_missing.plot(x=car_missing['Seats'],y=car_missing['Price'], xlabel='CAR Seats',ylabel="CAR PRICES")
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     935                 if is_integer(x) and not data.columns.holds_integer():
#     936                     x = data_cols[x]
# --> 937                 elif not isinstance(data[x], ABCSeries):
#     938                     raise ValueError("x must be a label or position")
#     939                 data = data.set_index(x)
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# ...

# %%
car_missing['Seats']=car_missing['Seats'].astype(int)
car_missing
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 4  Nissan  White         213095    4.0   3500     10
# 0  Toyota  White         150043    4.0   4000      2
# 5  Toyota  Green          92302    4.0   4500     12
# 1   Honda    Red          87899    4.0   5000      4
# 2  Toyota   Blue          92302    3.0   7000      6
# 7   Honda   Blue          92302    4.0   7000      5
# 6   Honda    NaN          92302    4.0   7500      5
# 9     NaN  White          31600    4.0   9700      5
# 3     BMW  Black          11179    5.0  22000      8
# 8  Toyota  White          60000    4.0  80000      5

# %%
car_missing.plot()
# Out:
# <AxesSubplot:>

# %%
car_missing['seat_price']= car_missing['Price']/car_missing['Seats']
car_missing
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats    seat_price
# 4  Nissan  White         213095    4.0   3500     10    350.000000
# 0  Toyota  White         150043    4.0   4000      2   2000.000000
# 5  Toyota  Green          92302    4.0   4500     12    375.000000
# 1   Honda    Red          87899    4.0   5000      4   1250.000000
# 2  Toyota   Blue          92302    3.0   7000      6   1166.666667
# 7   Honda   Blue          92302    4.0   7000      5   1400.000000
# 6   Honda    NaN          92302    4.0   7500      5   1500.000000
# 9     NaN  White          31600    4.0   9700      5   1940.000000
# 3     BMW  Black          11179    5.0  22000      8   2750.000000
# 8  Toyota  White          60000    4.0  80000      5  16000.000000

# %%
car_missing.iat[5,4]=3000
car_missing['seat_price']= car_missing['Price']/car_missing['Seats']
car_missing
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats    seat_price
# 4  Nissan  White         213095    4.0   3500     10    350.000000
# 0  Toyota  White         150043    4.0   4000      2   2000.000000
# 5  Toyota  Green          92302    4.0   4500     12    375.000000
# 1   Honda    Red          87899    4.0   5000      4   1250.000000
# 2  Toyota   Blue          92302    3.0   7000      6   1166.666667
# 7   Honda   Blue          92302    4.0   3000      5    600.000000
# 6   Honda    NaN          92302    4.0   7500      5   1500.000000
# 9     NaN  White          31600    4.0   9700      5   1940.000000
# 3     BMW  Black          11179    5.0  22000      8   2750.000000
# 8  Toyota  White          60000    4.0  80000      5  16000.000000
