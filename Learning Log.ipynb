# %% [markdown]
# # Data Analytics : my understanding towards it

# %% [markdown]
# ## In this log I will be sharing what I have learned so far from the Google Data Analytics course.

# %% [markdown]
# ## Data Analysis:
# Data analysis is the collection, transformation, and organization of data in order to draw conclusions, make predictions, and drive informed decision-making.

# %% [markdown]
# Data analysis can be comprised of 6 steps:
# 1. Ask - Ask the people who are asking you for preparing the data
# 2. Prepare - Collect data from the people on whom the result needs to be applied
# 3. Process - Clean and make relevant changes to the collected data
# 4. Analyze - analyze data to make predictions
# 5. Share - Documenting everything that I have done so far and share the same with the leadership of the company
# 6. Act - Taking action as per the results from the data that was analyzed

# %% [markdown]
# ## Data Ecosystems:
#
# Elements that interact with one another in order to produce, manage, store, organize, analyze, and share data are data ecosystems. These elements include hardware and software tools, as well as the people who use them.

# %% [markdown]
# There are several other corporations as well who are following a similar to an identical method for doing analysis. Below are the examples of such other corporations.
#
# These all are the cyclic nature for data analysis
#
# #### a. EMC Corp. (EMC Corporation is now Dell EMC. This model, created by David Dietrich)
# 1. Ask - collect data
# 2. Pre-processing data
# 3. Discussing model
# 4. Building model
# 5. Communicate
# 6. Operationalize
#
# #### b. SAS's model (a leading data analytics solutions provider)
# 1. Ask
# 2. Prepare
# 3. Explore
# 4. Model/Build
# 5. Implement/Apply
# 6. Act
# 7. Evaluate

# %% [markdown]
# Data Scientists make new questions from the existing raw data.
# Data ecosystem

# %% [markdown]
# ## Analytical Skills
#
# These are the professional skills with the help of which one can analyze data , think critically make data driven decisions.
# Below are the essential skills of a data analyst:
#
# #### 1. Curosity
# #### 2. Understanding Context
# #### 3. Having a technical mindset
#  Breaking down large problems into smaller parts and them solving them in an orderly fashion
# #### 4. Data Design
#  How you organize data for example the way we save data on phone.
# #### 5. Data Strategy
#  Management of the people ,processes and tools used in data analysis.
#  For ex: Process of making tea
#  people involved: me and the ones who will drink it
#  processes involved: boiling water, adding ingredients, serving
#  tools involved: gas, utensils

# %% [markdown]
# ## Aspects to thinking analytically
#
# #### 1. Visualization
#  Graphical representation of data
# #### 2. Strategy
#  To make a strategic plan to understand What do we have to achieve. What are the procedure and steps. Following a strategic plan.
# #### 3. Problem orientation
#  To be problem oriented.
# #### 4. Co-relation
#  Identify corelation between two or more data. However, it is always not necessary if both the data are trending in the same direction they are corelated. This is known as causation.
# #### 5. Viewing the big picture
#  Need to zoom out of the current data in hand and try to identify the bigger picture to see the opportunities and possibilities.

# %% [markdown]
# ## Gap Analysis
#
#  In this analysis the gap between the current situation and the future situatuion where we want to be is analysed. We then try to bridge them.

# %% [markdown]
# ## Activity
#
# Here I have graded my analytical skills. The three grades mentioned are
#
# #### 1. Strength
# It meants that this analytical skill is my strength
# #### 2. Devloping
# It means that this analytical skill is under process i.e. I am learning more about them
# #### 3. Emerging
# It means that this particular skill is something I am curious now and I have started to gain more about it
#
# ![askill.png](attachment:askill.png)

# %% [markdown]
# #### Now the questions that come against the above activity are:
#
# Question 1. What do you notice about the ratings you gave yourself in each area? How did you rate yourself in the areas that appeal to you most?
#
# Question 2. If you are asked to rate your experience level in these areas again in a week, what do you think the ratings will be, and why do you think that?
#
# Question 3. How do you plan on developing these skills from now on?

# %% [markdown]
# Question 1. What do you notice about the ratings you gave yourself in each area? How did you rate yourself in the areas that appeal to you most?
#
# Answer:
# I noticed that the data design and data stragey are some what related to each other. I as a regular computer user tend to keep my files and data organized in order to easily have access to them. I tend to keep the files in a clean manner i.e. well aranged.
#
# Also, I make use of a windows feature called notes(tool in a data strategy) to easily identify my(user) day to day activity(process) .
#
# I am under a devloping grade for the curosity skill which appeals to me more. I rated myself as devloping because with every section or reading manual I am completing I want to learn more about it. It is for the first time I feel that I am enjoying doing something.
